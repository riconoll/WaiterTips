# %% [markdown]
# # Are there certain days where a server get better tips?
# Data Link:https://www.kaggle.com/jsphyg/tipping?select=tips.csv
#
# By: Jon-Jon Rico-Noll
#
# A male server recorded every transaction from Thursday to Sunday and Lunch or Dinner.
# It also showcase the total amount of the bill, tip they received, whether the guest were smokers or not, and they did by gender as well.
#
# My hypothesis is that Friday and Saturday will have better tips base on percentage.
# A normal tip percentage is between 15% to 18% of the total_bill

# %% [markdown]
# ## Uploading the Data and Libraries

# %%
import pandas as pd

# %%
df = pd.read_csv('./tips.csv')
# Pull the data from the folder

# %%
df
# Let's print the data and see what were working with
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## A Quick Overview
# Let's create a new column that shows the tip percentage of each bill

# %%
def percentage (tip, bill): 
     return (tip/bill) * 100
(df['tip_percentage']) = percentage(df['tip'], df['total_bill'])

# Let's divide the tips with the total_bill and multiply by 100.
# This will give us percentage the guest tip

# %%
pd.set_option('display.max_rows',1000)
# With this code, we can have look of the whole table.
# At quick glance, there's good and bad tippers.
# Let's explore the server's tip by the days
df
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 0         16.99   1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34   1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01   3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68   3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59   3.61  Female     No   Sun  Dinner     4       14.680765
# 5         25.29   4.71    Male     No   Sun  Dinner     4       18.623962
# 6          8.77   2.00    Male     No   Sun  Dinner     2       22.805017
# 7         26.88   3.12    Male     No   Sun  Dinner     4       11.607143
# 8         15.04   1.96    Male     No   Sun  Dinner     2       13.031915
# 9         14.78   3.23    Male     No   Sun  Dinner     2       21.853857
# 10        10.27   1.71    Male     No   Sun  Dinner     2       16.650438
# 11        35.26   5.00  Female     No   Sun  Dinner     4       14.180374
# ...

# %% [markdown]
# ## Tips by Days
# Let's calculate the average tips by percentage broken down to the days the server worked

# %%
daySales = df.groupby('day').sum()
# Created a new dataframe
# Group by day and get the sum of the bill, tips and how many guest were served

# %%
daySales['tip_percentage'] = percentage(daySales['tip'],daySales['total_bill'])
# Since we have a new dataframe will need to recalculate and add the column of the tip_percentage

# %%
daySales
# With this date presented - it seems the server had a better tip percentage Thursday and Friday
# Though looking at the dataframe, it seems the less guest served the higher the tip percentage is
# This can factor whether there has been a change of the way service went. 
# Example: If the restaurant filled out quickly and service slowed down due to all the guest arrving all at once
# Tips are dependable on the amount of guest served and service.
# Out:
#       total_bill     tip  size  tip_percentage
# day
# Fri       325.88   51.96    40       15.944519
# Sat      1778.40  260.40   219       14.642375
# Sun      1627.16  247.39   216       15.203791
# Thur     1096.33  171.83   152       15.673201

# %%
# What about the average tip

for day in df['day'].unique():
    mean = df[df['day'] == day]['tip_percentage'].mean()
    print(f'Day: {day} the mean was: {round(mean,2)}%')
# Friday and Sunday seems to have a higher average of tip per bill.
# Because the data doesn't have the same amount of trasaction per day, the of mean is the suited for the data
# Out:
# Day: Sun the mean was: 16.69%
# Day: Sat the mean was: 15.32%
# Day: Thur the mean was: 16.13%
# Day: Fri the mean was: 16.99%

# %% [markdown]
# ## Conclusion
# Depending on the business whether it is slow or busy, factors that affect tip percentage depend on quality of service. A consistent service may affect the tip percentage to be consistent as well.
# Granted the server working a busy day or times will grant more money though the tip percentage decrease. It may be because of service or just how the guest are.

# %% [markdown]
# # Explorative Data
# Looking at other aspect whether tips will be higher by time
# Or does gender have a factor on tipping?

# %% [markdown]
# ## Lunch or Dinner

# %%
lunchData = df[df['time'] == 'Lunch']

# %%
lunchData
# The data showcase the server only working lunch Thursday and very little Friday
# Out:
#      total_bill   tip     sex smoker   day   time  size  tip_percentage
# 77        27.20  4.00    Male     No  Thur  Lunch     4       14.705882
# 78        22.76  3.00    Male     No  Thur  Lunch     2       13.181019
# 79        17.29  2.71    Male     No  Thur  Lunch     2       15.673800
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2       15.432099
# 81        16.66  3.40    Male     No  Thur  Lunch     2       20.408163
# 82        10.07  1.83  Female     No  Thur  Lunch     1       18.172790
# 83        32.68  5.00    Male    Yes  Thur  Lunch     2       15.299878
# 84        15.98  2.03    Male     No  Thur  Lunch     2       12.703379
# 85        34.83  5.17  Female     No  Thur  Lunch     4       14.843526
# 86        13.03  2.00    Male     No  Thur  Lunch     2       15.349194
# 87        18.28  4.00    Male     No  Thur  Lunch     2       21.881838
# 88        24.71  5.85    Male     No  Thur  Lunch     2       23.674626
# ...

# %%
dinnerData = df[df['time'] == 'Dinner']

# %%
dinnerData
# Majority dinner is from Friday Sunday
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 0         16.99   1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34   1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01   3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68   3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59   3.61  Female     No   Sun  Dinner     4       14.680765
# 5         25.29   4.71    Male     No   Sun  Dinner     4       18.623962
# 6          8.77   2.00    Male     No   Sun  Dinner     2       22.805017
# 7         26.88   3.12    Male     No   Sun  Dinner     4       11.607143
# 8         15.04   1.96    Male     No   Sun  Dinner     2       13.031915
# 9         14.78   3.23    Male     No   Sun  Dinner     2       21.853857
# 10        10.27   1.71    Male     No   Sun  Dinner     2       16.650438
# 11        35.26   5.00  Female     No   Sun  Dinner     4       14.180374
# ...

# %%
timeSales = df.groupby('time').sum()
timeSales['tip_percentage'] = percentage(timeSales['tip'],timeSales['total_bill'])

# %%
timeSales
# Base on the total sales between Lunch and Dinner sales; at time it is not to hectic the tip percentage seems hight
# Though not making more money wise but the percentage is higher
# Dinner sales tip percentage is lower but the more money.
# This can also be depending on quality or service or guest mood
# Out:
#         total_bill     tip  size  tip_percentage
# time
# Dinner     3660.30  546.07   463       14.918723
# Lunch      1167.47  185.51   164       15.889916

# %% [markdown]
# ## Male or Female Guest
# Can we factor in whether the gender affect the tips?
# Now keep in mind, our server is Male

# %%
df.groupby('sex').size().plot(kind='bar') 
# Majority of the guest were male
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
genSales = df.groupby('sex').mean()
genSales['tip_percentage'] = percentage(genSales['tip'],genSales['total_bill'])

# %%
genSales
# Majority of our sales are from the male guest
# Female Guest then to spend less but tip higher
# While male guest spend more but doesn't tip as much as female guest
# Could it be our server is an attractive male and very charismatic with the female guest
# Out:
#         total_bill       tip      size  tip_percentage
# sex
# Female   18.056897  2.833448  2.459770       15.691779
# Male     20.744076  3.089618  2.630573       14.893976

# %% [markdown]
# ## Smoker or Non-Smoker

# %%
smokeSales = df.groupby('smoker').mean()
smokeSales['tip_percentage'] = percentage(smokeSales['tip'],smokeSales['total_bill'])

# %%
smokeSales
# Out:
#         total_bill       tip      size  tip_percentage
# smoker
# No       19.188278  2.991854  2.668874       15.592094
# Yes      20.756344  3.008710  2.408602       14.495374
